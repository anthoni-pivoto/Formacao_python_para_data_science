# %%
import pandas as pd

# %%
url = 'emissoes_CO2.xlsx'

# %%
dados_co2 = pd.read_excel(url)

# %%
dados_co2.head(10)
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
# 5  Afeganistão                AFG  1755    0.0     NaN   NaN  NaN      NaN
# 6  Afeganistão                AFG  1756    0.0     NaN   NaN  NaN      NaN
# 7  Afeganistão                AFG  1757    0.0     NaN   NaN  NaN      NaN
# 8  Afeganistão                AFG  1758    0.0     NaN   NaN  NaN      NaN
# 9  Afeganistão                AFG  1759    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# ...

# %%
pd.ExcelFile(url).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
dados_co2_percapita = pd.read_excel(url, sheet_name='emissoes_percapita')
dados_co2_percapita.head(10)
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
# 5  Afeganistão                AFG  1755    NaN     NaN   NaN  NaN      NaN
# 6  Afeganistão                AFG  1756    NaN     NaN   NaN  NaN      NaN
# 7  Afeganistão                AFG  1757    NaN     NaN   NaN  NaN      NaN
# 8  Afeganistão                AFG  1758    NaN     NaN   NaN  NaN      NaN
# 9  Afeganistão                AFG  1759    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# ...

# %%
dados_co2_fontes = pd.read_excel(url, sheet_name='fontes')

# %%
dados_co2_fontes.head(10)
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
# 5  Afeganistão                AFG  1755  [NONE]  [NONE]  [NONE]  [NONE]
# 6  Afeganistão                AFG  1756  [NONE]  [NONE]  [NONE]  [NONE]
# 7  Afeganistão                AFG  1757  [NONE]  [NONE]  [NONE]  [NONE]
# 8  Afeganistão                AFG  1758  [NONE]  [NONE]  [NONE]  [NONE]
# 9  Afeganistão                AFG  1759  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# ...

# %%
intervalo = pd.read_excel(url, sheet_name=0, usecols='A:D')

# %%
intervalo.head(10)
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750    0.0
# 1  Afeganistão                AFG  1751    0.0
# 2  Afeganistão                AFG  1752    0.0
# 3  Afeganistão                AFG  1753    0.0
# 4  Afeganistão                AFG  1754    0.0
# 5  Afeganistão                AFG  1755    0.0
# 6  Afeganistão                AFG  1756    0.0
# 7  Afeganistão                AFG  1757    0.0
# 8  Afeganistão                AFG  1758    0.0
# 9  Afeganistão                AFG  1759    0.0

# %%
intervalo2 = pd.read_excel(url, sheet_name=0, usecols='A:D', nrows=10)

# %%
intervalo2
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
dados_co2_percapita.to_excel('emissoes_percapita.xlsx', index=False)

# %%
pd.read_excel('emissoes_percapita.xlsx').head(10)
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
# 5  Afeganistão                AFG  1755    NaN     NaN   NaN  NaN      NaN
# 6  Afeganistão                AFG  1756    NaN     NaN   NaN  NaN      NaN
# 7  Afeganistão                AFG  1757    NaN     NaN   NaN  NaN      NaN
# 8  Afeganistão                AFG  1758    NaN     NaN   NaN  NaN      NaN
# 9  Afeganistão                AFG  1759    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# ...
